# %%
from vivarium import Artifact
import pandas as pd

# %%
old_artifact = Artifact('/mnt/team/simulation_science/pub/models/vivarium_gates_nutrition_optimization/artifacts/model12.0/pakistan.hdf')
new_artifact = Artifact('/mnt/team/simulation_science/pub/models/vivarium_gates_nutrition_optimization/artifacts/mean/pakistan.hdf')

# %%
keys_list =new_artifact.keys
keys_list
# Out:
# ['metadata.keyspace', 'metadata.locations', 'population.location']

# %%
for key in old_artifact.keys:
    if key in list(['metadata.keyspace','metadata.locations','population.location']):
        continue
    data = old_artifact.load(key)
    if isinstance(data, pd.DataFrame) and 'draw_0' in data.columns and data['draw_0'].dtype == float:
        data['mean_draw'] = data.filter(like='draw_').mean(axis=1)
        data = data.drop(columns=data.filter(like='draw_').columns)
        data = data.rename(columns={'mean_draw': 'draw_0'})

    new_artifact.write(key, data)

# %%
keys_list =new_artifact.keys
keys_list
# Out:
# ['metadata.keyspace',
#  'metadata.locations',
#  'population.location',
#  'population.structure',
#  'population.age_bins',
#  'population.demographic_dimensions',
#  'population.theoretical_minimum_risk_life_expectancy',
#  'covariate.age_specific_fertility_rate.estimate',
#  'covariate.stillbirth_to_live_birth_ratio.estimate',
#  'cause.maternal_abortion_and_miscarriage.raw_incidence_rate',
#  'cause.ectopic_pregnancy.raw_incidence_rate',
#  'risk_factor.low_birth_weight_and_short_gestation.exposure',
#  'risk_factor.low_birth_weight_and_short_gestation.distribution',
#  'risk_factor.low_birth_weight_and_short_gestation.categories',
#  'cause.maternal_disorders.raw_incidence_rate',
#  'cause.maternal_disorders.incident_probability',
#  'cause.maternal_disorders.cause_specific_mortality_rate',
#  'cause.maternal_disorders.mortality_probability',
#  'cause.maternal_disorders.ylds',
#  'risk_factor.hemoglobin_on_maternal_disorder.relative_risk',
#  'risk_factor.hemoglobin_on_maternal_disorder.paf',
#  'cause.maternal_hemorrhage.raw_incidence_rate',
#  'cause.maternal_hemorrhage.cause_specific_mortality_rate',
#  'cause.maternal_hemorrhage.incident_probability',
#  'risk_factor.hemoglobin_on_maternal_hemorrhage.relative_risk',
#  'risk_factor.hemoglobin_on_maternal_hemorrhage.paf',
#  'covariate.moderate_hemorrhage_probability.estimate',
#  'risk_factor.hemoglobin.mean',
#  'risk_factor.hemoglobin.standard_deviation',
#  'risk_factor.hemoglobin.pregnant_proportion_below_70_gL',
#  'maternal_bmi.prevalance_low_bmi_anemic',
#  'maternal_bmi.prevalence_low_bmi_non_anemic',
#  'maternal_interventions.ifa_coverage',
#  'maternal_interventions.ifa_effect_size',
#  'maternal_interventions.mms_stillbirth_rr',
#  'maternal_interventions.bep_stillbirth_rr']

# %%
new_artifact.load('cause.ectopic_pregnancy.raw_incidence_rate')
# Out:
#                                                    draw_0
# sex    age_start age_end    year_start year_end
# Female 0.000000  0.019178   2021       2022      0.000000
#        0.019178  0.076712   2021       2022      0.000000
#        0.076712  0.500000   2021       2022      0.000000
#        0.500000  1.000000   2021       2022      0.000000
#        1.000000  2.000000   2021       2022      0.000000
#        2.000000  5.000000   2021       2022      0.000000
#        5.000000  10.000000  2021       2022      0.000000
#        10.000000 15.000000  2021       2022      0.000005
#        15.000000 20.000000  2021       2022      0.003935
#        20.000000 25.000000  2021       2022      0.008638
#        25.000000 30.000000  2021       2022      0.012280
#        30.000000 35.000000  2021       2022      0.012974
#        35.000000 40.000000  2021       2022      0.007475
#        40.000000 45.000000  2021       2022      0.004814
#        45.000000 50.000000  2021       2022      0.002097
#        50.000000 55.000000  2021       2022      0.000000
#        55.000000 60.000000  2021       2022      0.000000
#        60.000000 65.000000  2021       2022      0.000000
#        65.000000 70.000000  2021       2022      0.000000
#        70.000000 75.000000  2021       2022      0.000000
#        75.000000 80.000000  2021       2022      0.000000
#        80.000000 85.000000  2021       2022      0.000000
#        85.000000 90.000000  2021       2022      0.000000
#        90.000000 95.000000  2021       2022      0.000000
#        95.000000 125.000000 2021       2022      0.000000
# Male   0.000000  0.019178   2021       2022      0.000000
#        0.019178  0.076712   2021       2022      0.000000
#        0.076712  0.500000   2021       2022      0.000000
#        0.500000  1.000000   2021       2022      0.000000
#        1.000000  2.000000   2021       2022      0.000000
#        2.000000  5.000000   2021       2022      0.000000
#        5.000000  10.000000  2021       2022      0.000000
#        10.000000 15.000000  2021       2022      0.000000
#        15.000000 20.000000  2021       2022      0.000000
#        20.000000 25.000000  2021       2022      0.000000
#        25.000000 30.000000  2021       2022      0.000000
#        30.000000 35.000000  2021       2022      0.000000
#        35.000000 40.000000  2021       2022      0.000000
#        40.000000 45.000000  2021       2022      0.000000
#        45.000000 50.000000  2021       2022      0.000000
#        50.000000 55.000000  2021       2022      0.000000
#        55.000000 60.000000  2021       2022      0.000000
#        60.000000 65.000000  2021       2022      0.000000
#        65.000000 70.000000  2021       2022      0.000000
#        70.000000 75.000000  2021       2022      0.000000
#        75.000000 80.000000  2021       2022      0.000000
#        80.000000 85.000000  2021       2022      0.000000
#        85.000000 90.000000  2021       2022      0.000000
#        90.000000 95.000000  2021       2022      0.000000
#        95.000000 125.000000 2021       2022      0.000000
